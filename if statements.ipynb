# %%
c = 10
d = 101

if c == 10:
    print("yes")
else:
    print("No")
# Out:
# yes

# %%
if c == 10:
    print("yes")
elif c == 9:
    print("Y")
else:
    print("No")
# Out:
# yes

# %%
if d + 6 == c:
    print("Great")
elif d <= c:
    print("Even Better")
else:
    print("Good attempt")
# Out:
# Good attempt

# %%
names = ["Feyi", "Charles", "K-Chukwu"]
print("Please enter your name to verify your registration status")
username = str(input())
if username in names:
    print("Registered")
else:
    print("You are not registered. Please contact administrator ")
# Out:
# Please enter your name to verify your registration status
# Feyi
# Registered
