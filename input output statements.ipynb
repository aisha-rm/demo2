# %%
"Inupt and Output statements"

#Outputs are simply print statements
# Out:
# 'Inupt and Output statements'

# %%
#this is my first notebook
#num1 = 1
num2 = 2
num2
# Out:
# 2

# %%
num1 = 52
num2 = 18
sumnum = num1 + num2
sumnum
print("The sum of 2 given numbers is", sumnum)
# Out:
# The sum of 2 given numbers is 70

# %%
#Format way of writing string
report = "There have been reports of ongoing enjoyment being carried out by {} % of coders"
report.format(12)
# Out:
# 'There have been reports of ongoing enjoyment being carried out by 12 % of coders'

# %%
#Using a print statement to give the report output above.
print(report.format(20))
# Out:
# There have been reports of ongoing enjoyment being carried out by 20 % of coders

# %%
percentOfCoders = 12
report = f"There have been reports of ongoing enjoyment being carried out by {percentOfCoders} % of coders"
print(report)
# Out:
# There have been reports of ongoing enjoyment being carried out by 12 % of coders

# %%
gross = 5
net = 3
print("The gross amount given is {} and net is {}, after tax of {} is removed.".format(gross, net, gross - net))
# Out:
# The gross amount given is 5 and net is 3, after tax of 2 is removed.

# %%
print(f"The gross amount given is {gross} and net is {net}, after tax of {gross-net} is removed.")
# Out:
# The gross amount given is 5 and net is 3, after tax of 2 is removed.

# %%
Input Expressions

# %%
name = input()
print("Hello", name)
# Out:
# Husaina
# Hello Husaina

# %%
print(f"Hello {name}")
# Out:
# Hello Husaina

# %%
print("Welcome to Kadatemy \n Please tell us your your full name")
name = str(input())
# Out:
# Welcome to Kadatemy
#  Please tell us your your full name
# Hussaina Abdallah

# %%
print("Hello! Welcome to Kadatemy.")
print("Please tell us your name.")
name = str(input())
print("Thank you,", name,"." "Please enter your email address")
email = input()
print("Thank you. We hope you enjoy your time with us.")
# Out:
# Hello! Welcome to Kadatemy.
# Please tell us your name.
# Aisha Mohammed
# Thank you, Aisha Mohammed .Please enter your email address
# aisharm13@gmail.com
# Thank you. We hope you enjoy your time with us.

# %%
print("Welcome to Kadatemy \n Please tell us your full name")

# Using input with a specific data type
fullname = str(input())
print(f"Thank you {fullname}. Now proceed to the next stage. \n Kindly insert your email address")

email = str(input())
print("One more thing - We need to know your age. Please input it below")

age = int(input())
print("We got that. Thank you!")
# Out:
# Welcome to Kadatemy
#  Please tell us your full name
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-5-6f2fceb35535> in <module>
#       2
#       3 # Using input with a specific data type
# ----> 4 fullname = str(input())
#       5 print(f"Thank you {fullname}. Now proceed to the next stage. \n Kindly insert your email address")
#       6
#
# ~\anaconda3\lib\site-packages\ipykernel\kernelbase.py in raw_input(self, prompt)
#     858                 "raw_input was called, but this frontend does not support input requests."
#     859             )
# --> 860         return self._input_request(str(prompt),
#     861             self._parent_ident,
#     862             self._parent_header,
#
# ~\anaconda3\lib\site-packages\ipykernel\kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     902             except KeyboardInterrupt:
# ...
