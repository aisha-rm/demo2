# %% [markdown]
# **FXNS**

# %%
BMI = lambda weight, height : weight/height**2
    
weight = 78
height = 1.5


BMI(60, 2)
BMI(78,1.5)
# Out:
# 34.666666666666664

# %%
net = lambda total : total - (0.1*total)
net(10)
# Out:
# 9.0

# %%
basket = [1300, 200, 750, 1000]
net = lambda x : 0.9 * sum(x) 
net(basket)
# Out:
# 2925.0

# %%
basket = [1300, 200, 750, 1000]
net = lambda x : sum(x) - (0.1 * sum(x)) 
net(basket)
# Out:
# 2925.0
