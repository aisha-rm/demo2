# %%
import matplotlib.pyplot as plt

# %%
import numpy as np

# %%
t = np.arange(0, 2 , 0.1)
s = 1 + np.sin(2 *np.pi * t)
fix, ax = plt.subplots()
ax.plot (t, s)

plt.show()

# %%
t = np.arange(0, 2 , 0.1)
s = 1 + np.sin(2 *np.pi * t)
fix, ax = plt.subplots()
ax.plot (t, s)
ax.set(xlabel = 'time(s)', ylabel = 'voltage(mV)', title = 'Simple as 1, 2,3')
ax.grid()
plt.show()
fig.savefig("test.png")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-7108c754612c> in <module>
#       6 ax.grid()
#       7 plt.show()
# ----> 8 fig.savefig("test.png")
#
# NameError: name 'fig' is not defined

# %%
x = np.array
y = x*2([1, 2, 3 ])
plt.plot(x, y)

# %%
felines = ["cheetah", "puma", "jaguar", "leopard", "lion"]
percentages = [32, 18, 15, 15, 20]
explode = (0.1, 0, 0, 0, 0)

figl, axl = plt.subplots()
axl.pie(percentages, explode=explode, labels=felines, autopct='%1.1f%%', shadow=True, startangle=0)
axl.axis('equal')
plt.show()

# %%
#creating dataset
cars = ['Mercedes', 'Toyota', 'Mini Cooper', 'Range Rover', 'BMW', 'Audi']
data = [23, 29, 12, 21, 41, 17]
#create plot
fig = plt.figure(figsize = (10, 7))
plt.pie(data, labels = cars)
#show plot
plt.show()

# %%
#creating dataset
cars = ['Mercedes', 'Toyota', 'Mini Cooper', 'Range Rover', 'BMW', 'Audi']
data = [23, 29, 12, 21, 41, 17]
#create plot
fig = plt.figure(figsize = (7, 7))
plt.pie(data, labels = cars, autopct = '%1.0f%%')
#show plot
plt.show()

# %%
labels = "Frogs", "Hogs", "Dogs", "Logs"
sizes = [15, 30, 45, 10]
explode =

# %%
import matplotlib.mlab as mlab
x =[12, 111, 32, 21, 4, 2, 67, 54, 89, 77, 90, 3, 21, 55, 66, 73, 75, 77, 87]
num_bins = 5
n, bins, patches = plt.hist(x, num_bins, facecolor="pink", alpha = 0.9, ec='black')
plt.show()

# %%
#create dataset
a = np.array([22, 87, 43, 5, 56, 73, 55, 54, 11, 20, 51, 5, 79, 31, 27])
# create histo
fig,ax = plt.subplots(figsize = (10, 7))
ax.hist(a, bins = [0, 25, 50, 75, 100], ec='black')
#show plot
plt.show()
